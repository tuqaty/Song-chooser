# %%
from experta import *
import experta as py 
from tkinter import *  
from tkinter import ttk
from tkinter import font  as tkfont 
from pygame import mixer
import os
import time
# Out:
# pygame 2.4.0 (SDL 2.26.4, Python 3.8.3)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
 
class temp ():
    
    def __init__(self):
        print ("hi")
tem = temp()

class SampleApp(Tk):

    def __init__(self, *args, **kwargs):
        Tk.__init__(self, *args, **kwargs)

        self.title_font = tkfont .Font(family='Helvetica', size=18, weight="bold", slant="italic")
        container = Frame(self)
        container.pack(side="top", fill="both", expand=True)
        container.grid_rowconfigure(0, weight=1)
        container.grid_columnconfigure(0, weight=1)

        
        
        self.frames = {}
        for F in (startPage , First , Second ,Malad_select_Child,Health_select_Child,Sele,Health_select,Occasion_select,Time_select,State,StateH,lan_Select,Gender,Genderlast,work,KindSport,EndDayMood1,Mood_select,Malad_select,LastFrame):
  
            page_name = F.__name__
            frame = F(parent=container, controller=self)
            self.frames[page_name] = frame
             

            frame.grid(row=0, column=0, sticky="nsew")

        self.show_frame("startPage")
        pad=3
        self._geom='200x200+0+0'
        self.geometry("{0}x{1}+0+0".format(
            self.winfo_screenwidth()-pad, self.winfo_screenheight()-pad))
        self.bind('<Escape>',self.toggle_geom)            
    def toggle_geom(self,event):
        geom=self.winfo_geometry()
        print(geom,self._geom)
        self.geometry(self._geom)
        self._geom=geom
    def show_frame(self, page_name):
        '''Show a frame for the given page name'''
        frame = self.frames[page_name]
        frame.tkraise()
        
def playFilesFromDir(fileName):
        path = fileName
        fileList = os.listdir(path)
        for file in fileList:
            print(file)
            file_CONTENT = open( (fileName+ file), 'r')
            mixer.init()
            mixer.music.load(fileName+ file)
            mixer.music.play()
            #time.sleep(40)
# Out:
# hi

# %%
class Person ():
    def __init__ (self):
        self.age = 0 
        self.malad = 0
        self.patient  = 5
        self.patientChild=4
        self.timeChild =0
        self.maladChild =0
        self.KindSport1 =4
        self.time1 =0
     
        self.Occasion =0
        self.work1 =0
        self.EndDayMood=0
        self.State1=0
        self.State11=0
        self.Gender1=0
        self.Gender2=0
        self.Mood1=0
        self.Select1=0
        self.Sele1=0
        self.lan1=0
        self.SubAge=0
       
        
        
current = Person ()

# %%
############################
class age(Fact):
    pass

class patient(Fact):
    pass

class Mood1(Fact):
    pass

class time1(Fact):
    pass


class work1(Fact):
    pass

class Occasion(Fact):
    pass

class KindSport1(Fact):
    pass 


class malad(Fact):
    pass

class timeChild(Fact):
    pass

class patientChild(Fact):
    pass

class maladChild(Fact):
    pass

class EndDayMood(Fact):
    pass

class State1(Fact):
    pass
class State11(Fact):
    pass

class Gender1(Fact):
    pass
class Gender2(Fact):
    pass

class SubAge(Fact):
    pass
class SubAge1(Fact):
    pass

class Select1(Fact):
    pass
class Sele1(Fact):
    pass
class lan1(Fact):
    pass

# %%
class eng(KnowledgeEngine):
    
    @DefFacts()
    def _init_ (self): 
        yield age(self.person.age)
        
    
        
    @Rule(age(P(lambda value: value > 16)))
    def age_adult(self):
        print ("age  > 16 " , self.person.patient)
        self.declare(patient(x= self.person.patient ))
         
 ##############مناسبة بالغ سليم ###########################   
    @Rule(patient(x=1))
    def patient_occ(self):
        self.declare(Select1( x=self.person.Select1)) 
        
    @Rule(Select1(x=3))
    def selectoccasion(self):
        self.declare(Occasion( x=self.person.Occasion))   
    
        
    @Rule(Occasion(x=0))
    def Occasion_occ1(self):
        print ("graduated")
        playFilesFromDir('Success/')
        
      
    @Rule(Occasion(x=1))
    def Occasion_occ2(self):
        print ("Wedding")
        playFilesFromDir('Wedding/')
       
        
    @Rule(Occasion(x=2))
    def Occasion_occ(self):
        print ("Birth Day")
        playFilesFromDir('Birthday/')
        
    
    
        ########################################################################################
      ###############وقت سليم بالغ############################################################################### 
 
    @Rule(patient(x=1))
    def patient_time(self):
        print("سليم")
        self.declare(Select1( x=self.person.Select1)) 
    
        
    @Rule(Select1(x=2))
    def selecttime(self):
        
        self.declare(time1( x=self.person.time1))  
        
    @Rule(time1(x=1))
    def StartOfDay(self):
        print ("Morning")
        playFilesFromDir('بداية النهار/')  
       
        
        
        
    ##########$$$$$$$@@@@@@@@    
        
        
    @Rule(time1(x=2))
    def time_morning(self):
        print ("EarlyMorning")
        self.declare(Sele1(x=self.person.Sele1))
        
    @Rule(Sele1(x=1))
    def sele1(self):
        print ("وطني")
        playFilesFromDir('الصباح وطني/')  
        
        
    @Rule(Sele1(x=2))
    def sele2(self):
        print ("حالة اجتماعية")
        self.declare(State1(x= self.person.State1))
        
        
    @Rule(State1(x=1))
    def takenMorningAdult(self):
        playFilesFromDir('مرتبط الصباح/')
        
        
    @Rule(State1(x=2))
    def nonTakenMorningAdult(self):
        playFilesFromDir('الصباح غير مرتبط/')
       
        
    @Rule(State1(x=3))
    def EXMorningAdult(self):
        playFilesFromDir('الصباح منفصل/')
        
        
        
        ####$$$$$$@@@@@
    @Rule(time1(x=3))
    def time_work(self):
        print ("Working")
        self.declare(work1( x=self.person.work1))
    
    @Rule(work1(x=1))
    def erDefAdult(self):
        playFilesFromDir('عمل مهندس/')
      
        
    @Rule(work1(x=2))
    def programmerDefAdult(self):
        playFilesFromDir('عمل مبرمج/')
   
        
    @Rule(work1(x=3))
    def prefAdult(self):

        playFilesFromDir('classical/')
        
        
###############قيادة السيارة      
    
    @Rule(time1(x=4))
    def time_drive(self):
        print ("Driving")
        playFilesFromDir('classical/')
       
        
 #####**********نهاية اليوم      
    @Rule(time1(x=5))
    def time_end(self):
        print ("End Of Day")
        self.declare(EndDayMood(x= self.person.EndDayMood))
        
    @Rule(EndDayMood(x=1))
    def evningLoveAdult(self):
        print("Love")
        self.declare(Gender2( z=self.person.Gender2))
        
    @Rule(Gender2(z=2))
    def evningLoveMaleAdult(self):
        print("male")
        
        playFilesFromDir('الحب 16 ذكر المسا/')

    @Rule(Gender2(z=1))
    def evningLoveFemaleAdult(self):
        print("Famle")
        
        playFilesFromDir('الحب ٣٠ انثى عربي المسا/')
        
    
 #####################
    @Rule(EndDayMood(x=2))
    def evningHappyAdult(self):
        print("Happy")
        playFilesFromDir('نهاية اليوم سعيد/')
        
        
#########################
    @Rule(EndDayMood(x=3))
    def evningSad1111Adult(self):
        print('Sad')
        self.declare(State1( g2=self.person.State1))
        
    @Rule(State1(g2=1))
    def e33vningSadAdult1(self):
        playFilesFromDir('حزن المساء  مرتبط/')
       
        
    @Rule(State1(g2=2))
    def evn44ingSadAdult2(self):
        playFilesFromDir('حزن المساء غير مرتبط/')
       
    @Rule(State1(g2=3))
    def evnin66gSadAdult3(self):
        playFilesFromDir('المساء حزين منفصل ١٦/')
       

            
 ################################################################
    @Rule(EndDayMood(x=4))
    def evningdepressionAdult(self):
        print("Deprission")
        #البحث عن اغاني نهاية اليةم مكتئب
        playFilesFromDir('قبل النوم واحد/')
        
    @Rule(EndDayMood(x=5))
    def fearmoodDay(self):
        print("Fear")
        
        playFilesFromDir('الخوف موسيقى ذكر/')
        
    
####****   النوم 
    @Rule(time1(x=6))
    def time_sleep(self):
        print ("Sleeping")
        playFilesFromDir('قبل النوم واحد/')
  ###****  الرياضة    
    @Rule(time1(x=7))
    def time_sport(self):
        print ("Sporting")
        self.declare(KindSport1( x=self.person.KindSport1))
        
    @Rule(KindSport1(x=1))
    def footballAdult(self):
        playFilesFromDir('كرة قدم/')
        
        
    @Rule(KindSport1(x=2))
    def yogaAdult(self):
        playFilesFromDir('اليوغا/')
        
    
    @Rule(KindSport1(x=3))
    def warmUpAdult(self):
        playFilesFromDir('pop/')
       
        
    @Rule(KindSport1(x=4))
    def runningAdult(self):
        playFilesFromDir('rock/')
       
        
    @Rule(KindSport1(x=5))
    def mix(self):
        #البحث عن اغنية لكافة انواع الرياضة
        playFilesFromDir('hop/')
        

###########################################################################################################
###########################################################################################################
 ###########################################################################################################       
 
     
    @Rule(patient(x=1))
    def moodDefAdult(self):
        self.declare(Select1( x=self.person.Select1)) 
        
    @Rule(Select1(x=1))
    def selectmood(self):
        self.declare(Mood1( x=self.person.Mood1))
          
   ######################################حب
    @Rule(Mood1(x=1))
    def loveAdult(self):
        print("love")
        self.declare(Gender2( b=self.person.Gender2))
        
    @Rule(Gender2(b=1) )
    def lovefeMaleAdul(self):
      
        if ((self.person.age > 16) & (self.person.age <= 30)):
  
            playFilesFromDir('الحب ١٦ انثى عربي الصبح/')
            print("love female 20")
            
            
        if ((self.person.age > 30) & (self.person.age <= 40)):
        
    
   
            playFilesFromDir('الحب ٣٠ انثى عربي المسا/')
            print("love female 30")
            
            
        if (self.person.age > 40):
            
            playFilesFromDir('الحب ٤٠ انثى عربي/')
            print("love Female 40")
            
            
        
    
        
    @Rule(Gender2(b=2))
    def lovemaleAdult(self):
       # self.declare(age( m
        if ((self.person.age > 16) & (self.person.age <= 30)):
    
            playFilesFromDir('الحب 16 ذكر المسا/')
            print("love male 20")
          
        
        if (self.person.age > 30):
    
            playFilesFromDir('الحب ٣٠ ذذكر عربي/')
            print("love male 30")
            
         
            
            
            
            ######################################سعيد##########################################################
    @Rule(Mood1(x=3))
    def happyAdult(self):
        self.declare(State11( x=self.person.State11))
    
    
    @Rule(State11(x=1))
    def takenHappyAdult(self):
        self.declare(Gender2( q=self.person.Gender2))
     
    @Rule(Gender2(q=1))
    def takenFemaleHappyAdult(self):
        if ((self.person.age > 16) & (self.person.age <= 30)):
    
            playFilesFromDir('السعادة مرتبط انثى ١٦/')
            print("love male 20")
           
        if ((self.person.age > 30) & (self.person.age <= 40)):
    
            playFilesFromDir('السعادة مرتبط انثى ٣٠/')
            print("love male 30")
            
        if (self.person.age > 40):
            playFilesFromDir('السعادة مرتبط انثى 40/')
            print("love male 40")
            
       

 
                  
    @Rule(Gender2(q=2))
    def takenMaleHappyAdult(self):
        if ((self.person.age > 16) & (self.person.age <= 30)):
    
            playFilesFromDir('السعادة مرتبط ذكر ١٦/')
                             
            print("love male 20")
            
        
        if ((self.person.age > 30) & (self.person.age <= 40)):
            playFilesFromDir('لسعادة مرتبط ذكر ٣٠/')

            print("love male 30")
            
            
        if (self.person.age > 40):
            playFilesFromDir('السعادة مرتبط ذكر ٤٠/')
            print("love male 40")
            
        
    
          
    @Rule(State11(x=2))
    def nonTakenHappyAdult(self):
        self.declare(Gender2( q1=self.person.Gender2))
    
          
    @Rule(Gender2(q1=2))
    def nonTakenFemaleHappyAdult(self):
        if ((self.person.age > 16) & (self.person.age <= 30)):
            playFilesFromDir('السعادة غير مرتبط انثى ١٦/') 
           
        if (self.person.age > 40):
            playFilesFromDir('السعادة غير مرتبط انثى ٣٠/')  
            
    
          
    @Rule(Gender2(q1=1))
    def nonTakenMaleHappyAdult(self):
        if ((self.person.age > 16) & (self.person.age <= 30)):
            playFilesFromDir('لسعادة غير مرتبط ذكر ١٦/') 
           
        if (self.person.age > 40):
            playFilesFromDir('السعادة غير مرتبط ذكر ٣٠/')  
            
    
        
        
     
        
        
        #######################################خوف#############################################
    @Rule(Mood1(x=6))
    def f5cdsult(self):
        playFilesFromDir('اكتئاب/')
        
        
    @Rule(Mood1(x=4))
    def fearAdult(self):
        self.declare(Gender2( r=self.person.Gender2))
    
    @Rule(Gender2(r=1))
    def fearMaleAdult(self):
        print("male")
        playFilesFromDir('الخوف موسيقى ذكر/')
      
    
    @Rule(Gender2(r=2))
    def fearFemaleAdult(self):
        print("female")
        playFilesFromDir('الخوف موسيقى انثى/')
        
          
        ######################################غضب##########################################################
    
    @Rule(Mood1(x=5))
    def madAdult(self):
        print("fg")
        self.declare(Gender1( x1=self.person.Gender1))
    
   
        
    
    @Rule(Gender1(x1=1))
    def arabicMaleMadAdult(self):
        print("hj")
        self.declare(lan1(v=self.person.lan1))
          
    @Rule(lan1(v=1))
    def arabicMadAdultgg(self):
        print("arabic")
        playFilesFromDir('الغضب عربي انثى/')
        
        
    @Rule(lan1(v=2))
    def englishMadAdult(self):
        if ((self.person.age > 16) & (self.person.age <= 30)):
            playFilesFromDir('الغضب إنكليزي ١٦ انثى/')
        if ((self.person.age > 30) & (self.person.age <= 40)):
            playFilesFromDir('الغضب إنكليزي ٣٠ انثى/')
        if (self.person.age > 40):
            playFilesFromDir('الغضب إنكليزي ٤٠ انثى/')
            
    
    @Rule(Gender1(x1=2))
    def arabicFemaleMadAdult(self):
        self.declare(lan1( l=self.person.lan1))
    @Rule(lan1(l=1))
    def arabicMadAdult(self):
        playFilesFromDir('الغضب عربي ذكر/')
        
        
    @Rule(lan1(l=2))
    def english11MadAdult(self):
        if ((self.person.age > 16) & (self.person.age <= 30)):
            playFilesFromDir('الغضب إنكليزي ١٦ انثى/')
        if ((self.person.age > 30) & (self.person.age <= 40)):
            playFilesFromDir('الغضب إنكليزي ٣٠ انثى/')
        if (self.person.age > 40):
            playFilesFromDir('الغضب إنكليزي ٤٠ انثى/')
        
 
   
    
     ######################################حزن#################
    
    @Rule(Mood1(x=2))
    def sad6765Adult(self):
        print("Cry Sad")
        self.declare(Gender2(x11=self.person.Gender2))
        
    @Rule(Gender2(x11=1))
    def maleSadAdult(self):
        
                             
                             
        if ((self.person.age > 16) & (self.person.age <= 30)):
            playFilesFromDir('حزن أنثى 1/')                 
            
                             
                             
        if ((self.person.age > 30) & (self.person.age <= 40)):

        

            playFilesFromDir('الحزن عربي ٣٠ انثى/') 
            
        if (self.person.age > 40):
            playFilesFromDir('حزن أنثى 3/') 
            
   
        
    @Rule(Gender2(x11=2))
    def femaleSadAdult(self): 
        if ((self.person.age > 16) & (self.person.age <= 30)):
            playFilesFromDir('ذكر حزن 1/')                 
            
                             
                             
        if (self.person.age > 30):
        

            playFilesFromDir('ذكر حزن 2/')
            
        

        
    
    
        
##########مريض بالغ ############################################################################



    @Rule(patient(x=2))
    def patient(self):
        print ("malad ",self.person.malad)
        self.declare(malad( x=self.person.malad))



    @Rule(malad(x=5))
    def pregnancy(self):
        playFilesFromDir('Pregnancy/')
        
    
    @Rule(malad(x=7))
    def heartAdult(self):
        playFilesFromDir('قلب/')
        
        
    @Rule(malad(x=0))
    def deprissionAdult(self):
        playFilesFromDir('Depression and Heart Diseases/')
       
     
        
       
    @Rule(malad(x=8))
    def earsAdult(self):
        playFilesFromDir('Natural Sounds/')
        
       
        
    @Rule(malad(x=6))
    def cancerAdult(self):
        playFilesFromDir('Cancer/')
       
       
    
    @Rule(malad(x=4))
    def earsAdult22(self):
        playFilesFromDir('Dizziness/')
        
        
        
    @Rule(malad(x=9))
    def sleepAdult(self):
        playFilesFromDir('Sleep problems/') 
        
       
        
    @Rule(malad(x=1))
    def highBlood(self):
        playFilesFromDir('High Blood Pressure/')
       
       
    
    @Rule(malad(x=2))
    def lowBlood(self):
        playFilesFromDir('Low Blood pressure/')
       
        
          
           
    @Rule(malad(x=3))
    def senile(self):
        playFilesFromDir('خرف/')
        
        
    @Rule(malad(x=10))
    def Autism(self):
        print('توحد')
        playFilesFromDir('توحد/') 
       

        

        
    @Rule(age(P(lambda value: value <= 16)))
    def age_Child(self):
        print ("age  <= 16 " , self.person.patientChild)
        self.declare(patientChild(x= self.person.patientChild ))
         
 ##############Child سليم ####################################################################   
    @Rule(patientChild(x=1))
    def pati_(self):
        print ("healthy ",self.person.timeChild)
        self.declare(timeChild( x=self.person.timeChild)) 
        

    @Rule(timeChild(x=0))
    def sleepChild(self):
        print ("Sleep")
        playFilesFromDir('sleepChild/')
        
       
        
    @Rule(timeChild(x=1))
    def learnChild(self):
        print ("learning")
        playFilesFromDir('learn/')
    
    @Rule(timeChild(x=2))
    def morningChild(self):
        print ("Morning")
        playFilesFromDir('morningChild/')
    
    @Rule(timeChild(x=3))
    def motivationChild(self):
        print ("Motivation")
        playFilesFromDir('تحفيز/')
        
        
#############################  
    @Rule(patientChild(x=2))
    def patient_(self):
        print ("malad ",self.person.maladChild)
        self.declare(maladChild( x=self.person.maladChild)) 
        
    @Rule(maladChild(x=0))
    def deprissionSmall(self):
        playFilesFromDir('قلب/')
        
     
        
             
    @Rule(maladChild(x=1))
    def earsSmall(self):
        playFilesFromDir('Natural Sounds/')
        
       
        
    @Rule(maladChild(x=2))
    def cancerSmall(self):
        playFilesFromDir('Cancer/')
       
       
    
    @Rule(maladChild(x=3))
    def earsSmall(self):
        playFilesFromDir('Dizziness/')
        
        
        
    @Rule(maladChild(x=4))
    def sleepSmall(self):
        playFilesFromDir('Sleep problems/')
       
       
    
    @Rule(maladChild(x=5))
    def autismsmall(self):
        playFilesFromDir('توحد/')
        

    
    @Rule(maladChild(x=6))
    def mentalsmall(self):
        playFilesFromDir('Intellectual disability/')

# %%
en = eng()
person = Person()
class  startPage(Frame) :
    
    def __init__(self , parent , controller):
        Frame.__init__(self, parent)
        topFrame = Frame(self, width=720, height=1050, background='#4fc3f7')
        topFrame.pack(fill=X)
        MAIN = Frame(topFrame, width=700, height=1000, bd=1, relief="sunken", background='#e4f0ef')
        MAIN.pack(side=TOP, padx=10, pady=10, fill=BOTH)
        label = Label(MAIN, font=('arial', 15), text="Song Suggestion",
                  width=55, anchor="nw", justify=CENTER, background='#e4f0ef')
        label.pack(pady=5, side=TOP)
        button1 = Button(MAIN, padx=16, bd=8, text="START", fg="#01579b", command=lambda: controller.show_frame("First"))
        button1.pack(side = TOP)
        

class  First(Frame) :
  
    def __init__(self , parent , controller):
        Frame.__init__(self, parent)
        self.v =  IntVar()
        topFrame = Frame(self, width=720, height=1600, background='#4fc3f7')
        topFrame.pack(fill=X)
        
        MAIN = Frame(topFrame, width=360, height=1500, bd=1, relief="ridge", background='#e4f0ef')
        MAIN.pack(side=TOP, padx=10, pady=10, fill=BOTH)
        label = Label(MAIN, font=('arial', 15), text="Personal Information",
                  width=55, anchor="nw", justify=CENTER, background='#e4f0ef')
        label.pack(pady=5, side=TOP)
        Label(MAIN,   text="Age ",    justify = LEFT,   padx = 50).pack()
        self.tb = Entry(MAIN,text=""  )
        self.tb.pack(anchor=CENTER) 
     
        button1 = Button(MAIN, padx=16, bd=8, text="NEXT", fg="#01579b", command=lambda: self.saveDataFirst(controller))
        button1.pack(side = TOP)  
        button2 = Button(MAIN, padx=16, bd=8, text="BACK", fg="#01579b", command=lambda: self.ClearDataFirst(controller))
        button2.pack(side = TOP)
        
    def saveDataFirst(self , controller):
       
        current.age  = int (self.tb.get())
        
        controller.show_frame("Second")
        
    def ClearDataFirst(self , controller):
        controller.show_frame("startPage")    
    
        
        
class  Second(Frame) :
  
    def __init__(self , parent , controller):
        Frame.__init__(self, parent)
        self.v =  IntVar()
        topFrame = Frame(self, width=720, height=1600, background='#4fc3f7')
        topFrame.pack(fill=X)  
        MAIN = Frame(topFrame, width=700, height=1500, bd=1, relief="ridge", background='#e4f0ef')
        MAIN.pack(side=TOP, padx=10, pady=10, fill=BOTH)
        
        label = Label(MAIN, font=('arial', 15), text="maladالحالة الصحية",
                  width=55, anchor="nw", justify=CENTER, background='#e4f0ef')
        label.pack(pady=5, side=TOP)
        self.rb1 = Radiobutton(MAIN,text="Healthyسليم",  padx = 20,   variable=self.v, value=1)# , selectcolor="blue")
        self.rb1.pack(anchor=CENTER)
        self.rb2 = Radiobutton(MAIN,text="patientمريض",padx = 20,variable=self.v,value=2)
        self.rb2.pack(anchor=CENTER)
        button1 = Button(MAIN, padx=16, bd=8, text="NEXT", fg="#01579b", command=lambda: self.saveDataSecond(controller))
        button1.pack(side = TOP)
        
        button2 = Button(MAIN, padx=16, bd=8, text="BACK", fg="#01579b", command=lambda: self.ClearDataSecond(controller))
        button2.pack(side = TOP)
        
    def saveDataSecond(self,controller):
        if (self.v.get() == 1 ):
            if (current.age <= 15  ) :
                controller.show_frame("Health_select_Child")
                
        if (self.v.get() == 1 ):
            if (current.age > 15  ) :
                controller.show_frame("Health_select")
                
        if (self.v.get() == 2 ):
            if (current.age <= 15  ) :
                controller.show_frame("Malad_select_Child")
        if (self.v.get() == 2 ):
            if (current.age > 15   ) :
                controller.show_frame("Malad_select")
    
        current.patient =  (self.v.get())
        current.patientChild =  (self.v.get())
        print( "mimi " ,current.patient)
       
    def ClearDataSecond(self , controller):
        controller.show_frame("startPage") 

#############سليم وبالغ
class  Health_select(Frame) :
    def __init__(self , parent , controller):
        Frame.__init__(self, parent)
        self.v =  IntVar()
        self.name = StringVar()
        
        topFrame = Frame(self, width=720, height=1600, background='#4fc3f7')
        topFrame.pack(fill=X) 
        MAIN = Frame(topFrame, width=700, height=1500, bd=1, relief="ridge", background='#e4f0ef')
        MAIN.pack(side=TOP, padx=10, pady=10, fill=BOTH)
        
        label = Label(MAIN, font=('arial', 15), text="Select",
                  width=55, anchor="nw", justify=CENTER, background='#e4f0ef')
        label.pack(pady=5, side=TOP)
        self.rb1 = Radiobutton(MAIN,text="Mood مزاج",  padx = 20,   variable=self.v, value=1)
        self.rb1.pack(anchor=CENTER)
        self.rb2 = Radiobutton(MAIN,text="Time وقت",padx = 20,variable=self.v,value=2)
        self.rb2.pack(anchor=CENTER)
        self.rb3 = Radiobutton(MAIN,text="Occasionمناسبة ",padx = 20,variable=self.v,value=3)
        self.rb3.pack(anchor=CENTER) 
        button1 = Button(MAIN, padx=16, bd=8, text="NEXT", fg="#01579b", command=lambda: self.saveDataHealth(controller))
        button1.pack(side = TOP)
        
        button2 = Button(MAIN, padx=16, bd=8, text="BACK", fg="#01579b", command=lambda: self.ClearDataHealth(controller))
        button2.pack(side = TOP)
       
    def saveDataHealth(self , controller):
        if (self.v.get() == 1 ):
            controller.show_frame("Mood_select")
            
        if (self.v.get() == 2 ):
            controller.show_frame("Time_select")
        if (self.v.get() ==  3):
            controller.show_frame("Occasion_select")
            
        current.Select1 = (self.v.get()) 
        
        
        
           
       
    def ClearDataHealth(self , controller):
        controller.show_frame("startPage")
        
 ###########مناسبة وسليم وبالغ      
class Occasion_select(Frame):
  
    def __init__(self , parent , controller):
        Frame.__init__(self, parent)
        self.v =  IntVar()
        topFrame = Frame(self, width=720, height=1600, background='#4fc3f7')
        topFrame.pack(fill=X) 
        MAIN = Frame(topFrame, width=700, height=1500, bd=1, relief="ridge", background='#e4f0ef')
        MAIN.pack(side=TOP, padx=10, pady=10, fill=BOTH)
        
        Label(MAIN,   text="Occasion ",    justify = LEFT,   padx = 20).pack()
        rb1 = Radiobutton(MAIN,text="Graduated تخرج",  padx = 20,   variable=self.v, value=0)
        rb1.pack(anchor=CENTER)
        rb2 = Radiobutton(MAIN,text="Wedding زفاف ",padx = 20,variable=self.v,value=1)
        rb2.pack(anchor=CENTER)
        rb3 = Radiobutton(MAIN,text="BirthDay عيد ميلاد",  padx = 20,   variable=self.v, value=2)
        rb3.pack(anchor=CENTER)
        
        nextbutton = Button(MAIN, padx=16, bd=8, text="NEXT", fg="#01579b", command=lambda: self.saveDataOccasion(controller))
        nextbutton.pack(side = TOP)
        backbutton = Button(MAIN, padx=16, bd=8, text="BACK", fg="#01579b", command=lambda: self.ClearDataOccasion(controller))
        backbutton.pack(side = TOP)
        
        

    def saveDataOccasion(self , controller):
        controller.show_frame("LastFrame")
        current.Occasion = self.v.get() 
        en = eng()
        en.person= current
        en.reset()
        en.run()
        
        
        
    def ClearDataOccasion(self , controller):
        controller.show_frame("Health_select")


###############################################مزاج وسليم وبالغ        
class Mood_select(Frame): 
    def __init__(self , parent , controller):
        Frame.__init__(self, parent)
        self.v =  IntVar()
        topFrame = Frame(self, width=720, height=1600, background='#4fc3f7')
        topFrame.pack(fill=X)
    
        MAIN = Frame(topFrame, width=700, height=1500, bd=1, relief="ridge", background='#e4f0ef')
        MAIN.pack(side=TOP, padx=10, pady=10, fill=BOTH)
        Label(MAIN,   text="mood",    justify = LEFT,   padx = 20).pack()
        rb1 = Radiobutton(MAIN,text="love ",  padx = 20,   variable=self.v, value=1)
        rb1.pack(anchor=CENTER)
        rb2 = Radiobutton(MAIN,text="cry ",padx = 20,variable=self.v,value=2)
        rb2.pack(anchor=CENTER)
        rb3 = Radiobutton(MAIN,text="Happy ",  padx = 20,   variable=self.v, value=3)
        rb3.pack(anchor=CENTER)
        rb4 = Radiobutton(MAIN,text="fear ",  padx = 20,   variable=self.v, value=4)
        rb4.pack(anchor=CENTER)
        rb5 = Radiobutton(MAIN,text="angry ",  padx = 20,   variable=self.v, value=5)
        rb5.pack(anchor=CENTER)
        rb6 = Radiobutton(MAIN,text="Depression",  padx = 20,   variable=self.v, value=6)
        rb6.pack(anchor=CENTER)
        
        nextbutton = Button (self , text = 'NEXT' , command=lambda : self.saveDataMood(controller))
        nextbutton.pack()     
        backbutton = Button (self , text = 'BACK' , command=lambda : self.ClearDataMood(controller))
        backbutton.pack()
                

    def saveDataMood(self , controller):
        if (self.v.get() == 1 ):
            controller.show_frame("Genderlast")
            current.Mood1 = self.v.get()
        if (self.v.get() ==2 ):
            controller.show_frame("Genderlast")
            current.Mood1 = self.v.get()
        if (self.v.get() == 3 ):
            controller.show_frame("StateH")
            current.Mood1 = self.v.get()
        if (self.v.get() == 4 ):
            controller.show_frame("Genderlast")
            current.Mood1 = self.v.get()
        if (self.v.get() == 5 ):
            controller.show_frame("Gender")
            current.Mood1 = self.v.get()
        if (self.v.get() == 6 ):
            controller.show_frame("LastFrame")
            current.Mood1 = self.v.get()
            en = eng()
            en.person= current
            en.reset()
            en.run()
            
        
    def ClearDataMood(self , controller):
        controller.show_frame("Health_select")
        
###############  ################################################################
#################################################################################
#
#
######################$$$$$$$$$$$$$$$$#################$$$$$$$$$$###########
#
class Time_select(Frame):
  
    def __init__(self , parent , controller):
        Frame.__init__(self, parent)
        self.v =  IntVar()
        topFrame = Frame(self, width=720, height=1600, background='#4fc3f7')
        topFrame.pack(fill=X)
       
        MAIN = Frame(topFrame, width=700, height=1500, bd=1, relief="ridge", background='#e4f0ef')
        MAIN.pack(side=TOP, padx=10, pady=10, fill=BOTH)
       
        Label(MAIN,   text="time الوقت",    justify = LEFT,   padx = 20).pack()
        rb1 = Radiobutton(MAIN,text="StartOfDay ",  padx = 20,   variable=self.v, value=1)
        rb1.pack(anchor=CENTER)
        rb2 = Radiobutton(MAIN,text=" Early Morning ",padx = 20,variable=self.v,value=2)
        rb2.pack(anchor=CENTER)
        rb3 = Radiobutton(MAIN,text="Working ",  padx = 20,   variable=self.v, value=3)
        rb3.pack(anchor=CENTER)
        rb4 = Radiobutton(MAIN,text="Driving القيادة",  padx = 20,   variable=self.v, value=4)
        rb4.pack(anchor=CENTER)
        rb5 = Radiobutton(MAIN,text="End Of Day نهاية اليوم",  padx = 20,   variable=self.v, value=5)
        rb5.pack(anchor=CENTER)
        rb6 = Radiobutton(MAIN,text="Sleeping النوم",  padx = 20,   variable=self.v, value=6)
        rb6.pack(anchor=CENTER)
        rb7 = Radiobutton(MAIN,text="Sporting الرياضة",  padx = 20,   variable=self.v, value=7)
        rb7.pack(anchor=CENTER)
      
        
        nextbutton = Button(MAIN, padx=16, bd=8, text="NEXT", fg="#01579b", command=lambda: self.saveDatatime(controller))
        nextbutton.pack(side = TOP)
        backbutton = Button(MAIN, padx=16, bd=8, text="BACK", fg="#01579b", command=lambda: self.ClearDatatime(controller))
        backbutton.pack(side = TOP)
        

    def saveDatatime(self , controller):
        if (self.v.get() == 1 ):
            controller.show_frame("LastFrame")
            
            current.time1 = self.v.get()
            en = eng()
            en.person= current
            en.reset()
            en.run()
        if (self.v.get() == 2 ):
            controller.show_frame("Sele")
            current.time1 = self.v.get()
            
        if (self.v.get() ==  3):
            controller.show_frame("work")
            current.time1 = self.v.get()
        if (self.v.get() == 4 ):
            controller.show_frame("LastFrame")
            current.time1 = self.v.get() 
            en = eng()
            en.person= current
            en.reset()
            en.run()
        if (self.v.get() == 5 ):
            controller.show_frame("EndDayMood1")
            current.time1 = self.v.get()
        if (self.v.get() ==  6):
            controller.show_frame("LastFrame")
            current.time1 = self.v.get() 
            en = eng()
            en.person= current
            en.reset()
            en.run()
        if (self.v.get() ==  7):
            controller.show_frame("KindSport")
            current.time1 = self.v.get()
     
        
    def ClearDatatime(self , controller):
        controller.show_frame("Health_select")

        
class work(Frame):
  
    def __init__(self , parent , controller):
        Frame.__init__(self, parent)
        self.v =  IntVar()
        topFrame = Frame(self, width=720, height=1600, background='#4fc3f7')
        topFrame.pack(fill=X)
       
        MAIN = Frame(topFrame, width=700, height=1500, bd=1, relief="ridge", background='#e4f0ef')
        MAIN.pack(side=TOP, padx=10, pady=10, fill=BOTH)
       
        Label(MAIN,   text="Type of Work",    justify = LEFT,   padx = 20).pack()
        rb1 = Radiobutton(MAIN,text="Engineering مهندس",  padx = 20,   variable=self.v, value=1)
        rb1.pack(anchor=CENTER)
        rb2 = Radiobutton(MAIN,text="programmer مبرمج",padx = 20,variable=self.v,value=2)
        rb2.pack(anchor=CENTER)
        rb3 = Radiobutton(MAIN,text="Office عمل مكتبي",padx = 20,variable=self.v,value=3)
        rb3.pack(anchor=CENTER)
     
        nextbutton = Button (MAIN , text = 'NEXT' , command=lambda : self.saveDatawork(controller))
        nextbutton.pack()
        
        backbutton = Button (MAIN , text = 'BACK ' , command=lambda : self.ClearDatawork(controller))
        backbutton.pack()
        

    def saveDatawork(self , controller):         
        
        controller.show_frame("LastFrame")
        current.work1 = self.v.get() 
        en = eng()
        en.person= current
        en.reset()
        en.run()
        
      
    def ClearDatawork(self , controller):
        controller.show_frame("Health_select")


class KindSport(Frame):
  
    def __init__(self , parent , controller):
        Frame.__init__(self, parent)
        self.v =  IntVar()
        topFrame = Frame(self, width=720, height=1600, background='#4fc3f7')
        topFrame.pack(fill=X)
       
        MAIN = Frame(topFrame, width=700, height=1500, bd=1, relief="ridge", background='#e4f0ef')
        MAIN.pack(side=TOP, padx=10, pady=10, fill=BOTH)
        
        Label(MAIN,   text="KindOfSport",    justify = LEFT,   padx = 20).pack()
        rb1 = Radiobutton(MAIN,text="Football كرة القدم",  padx = 20,   variable=self.v, value=1)
        rb1.pack(anchor=CENTER)
        rb2 = Radiobutton(MAIN,text="Yougha يوغا",padx = 20,variable=self.v,value=2)
        rb2.pack(anchor=CENTER)
        rb3 = Radiobutton(MAIN,text="Warmup تحمية",  padx = 20,   variable=self.v, value=3)
        rb3.pack(anchor=CENTER)
        rb4 = Radiobutton(MAIN,text="Run ركض",  padx = 20,   variable=self.v, value=4)
        rb4.pack(anchor=CENTER)
        rb5 = Radiobutton(MAIN,text="Gym رياضات منوعة",  padx = 20,   variable=self.v, value=5)
        rb5.pack(anchor=CENTER)
     
        nextbutton = Button (MAIN , text = 'NEXT' , command=lambda : self.saveDatasport(controller))
        nextbutton.pack()
        
        backbutton = Button (MAIN , text = 'BACK ' , command=lambda : self.ClearDatasport(controller))
        backbutton.pack()
    def saveDatasport(self , controller):     
        controller.show_frame("LastFrame")
        current.KindSport1 = self.v.get() 
        en = eng()
        en.person= current
        en.reset()
        en.run()
    
    def ClearDatasport(self , controller):
        controller.show_frame("Health_select")

class EndDayMood1(Frame):
  
    def __init__(self , parent , controller):
        Frame.__init__(self, parent)
        self.v =  IntVar()
        topFrame = Frame(self, width=720, height=1600, background='#4fc3f7')
        topFrame.pack(fill=X)
    
        MAIN = Frame(topFrame, width=700, height=1500, bd=1, relief="ridge", background='#e4f0ef')
        MAIN.pack(side=TOP, padx=10, pady=10, fill=BOTH)
        Label(MAIN,   text="State",    justify = LEFT,   padx = 20).pack()
        rb1 = Radiobutton(MAIN,text="Love",  padx = 20,   variable=self.v, value=1)
        rb1.pack(anchor=W)
        rb2 = Radiobutton(MAIN,text="happy",padx = 20,variable=self.v,value=2)
        rb2.pack(anchor=W)
        rb3 = Radiobutton(MAIN,text="Cry",  padx = 20,   variable=self.v, value=3)
        rb3.pack(anchor=CENTER)
        rb4 = Radiobutton(MAIN,text="Depression",  padx = 20,   variable=self.v, value=4)
        rb4.pack(anchor=CENTER)
        rb5 = Radiobutton(MAIN,text="Fear ",  padx = 20,   variable=self.v, value=5)
        rb5.pack(anchor=CENTER)
      
        nextbutton = Button (self , text = 'NEXT' , command=lambda : self.saveDatamoo(controller))
        nextbutton.pack()     
        backbutton = Button (self , text = 'BACK' , command=lambda : self.ClearDatamoo(controller))
        backbutton.pack()
        

    def saveDatamoo(self , controller): 
        if (self.v.get() == 1 ):
            controller.show_frame("Genderlast")
            current.EndDayMood = self.v.get()
            
        if (self.v.get() == 2 ):
            controller.show_frame("LastFrame")
            current.EndDayMood = self.v.get() 
            en = eng()
            en.person= current
            en.reset()
            en.run()
            
        if (self.v.get() ==  3):
            controller.show_frame("State")
            current.EndDayMood = self.v.get() 
            
        if (self.v.get() == 4 ):
            controller.show_frame("LastFrame")
            current.EndDayMood = self.v.get() 
            en = eng()
            en.person= current
            en.reset()
            en.run()
        if (self.v.get() == 5 ):
            controller.show_frame("LastFrame")  
            current.EndDayMood = self.v.get() 
            en = eng()
            en.person= current
            en.reset()
            en.run()
       
            
    def ClearDatamoo(self , controller):
        controller.show_frame("startPage")

class State(Frame):
  
    def __init__(self , parent , controller):
        Frame.__init__(self, parent)
        self.v =  IntVar()
        topFrame = Frame(self, width=720, height=1600, background='#4fc3f7')
        topFrame.pack(fill=X)
    
        MAIN = Frame(topFrame, width=700, height=1500, bd=1, relief="ridge", background='#e4f0ef')
        MAIN.pack(side=TOP, padx=10, pady=10, fill=BOTH)
        Label(MAIN,   text="State",    justify = LEFT,   padx = 20).pack()
        rb1 = Radiobutton(MAIN,text="مرتبط",  padx = 20,   variable=self.v, value=1)
        rb1.pack(anchor=CENTER)
        rb2 = Radiobutton(MAIN,text="غير مرتبط",padx = 20,variable=self.v,value=2)
        rb2.pack(anchor=CENTER)
        rb3 = Radiobutton(MAIN,text="منفصل",  padx = 20,   variable=self.v, value=3)
        rb3.pack(anchor=CENTER)
        nextbutton = Button(MAIN, padx=16, bd=8, text="NEXT", fg="#01579b", command=lambda: self.saveDatastate2(controller))
        nextbutton.pack(side = TOP)
        backbutton = Button(MAIN, padx=16, bd=8, text="BACK", fg="#01579b", command=lambda: self.ClearDatastate2(controller))
        backbutton.pack(side = TOP)
    def saveDatastate2(self , controller): 
        controller.show_frame("LastFrame")
        current.State1= self.v.get()
        en = eng()
        en.person= current
        en.reset()
        en.run()
        
            
    def ClearDatastate2(self , controller):
        controller.show_frame("startPage")
        
class StateH(Frame):
  
    def __init__(self , parent , controller):
        Frame.__init__(self, parent)
        self.v =  IntVar()
        topFrame = Frame(self, width=720, height=1600, background='#4fc3f7')
        topFrame.pack(fill=X)
    
        MAIN = Frame(topFrame, width=700, height=1500, bd=1, relief="ridge", background='#e4f0ef')
        MAIN.pack(side=TOP, padx=10, pady=10, fill=BOTH)
        Label(MAIN,   text="State",    justify = LEFT,   padx = 20).pack()
        rb1 = Radiobutton(MAIN,text="مرتبط",  padx = 20,   variable=self.v, value=1)
        rb1.pack(anchor=CENTER)
        rb2 = Radiobutton(MAIN,text="غير مرتبط",padx = 20,variable=self.v,value=2)
        rb2.pack(anchor=CENTER)
        
        nextbutton = Button(MAIN, padx=16, bd=8, text="NEXT", fg="#01579b", command=lambda: self.saveDatastate11(controller))
        nextbutton.pack(side = TOP)
        backbutton = Button(MAIN, padx=16, bd=8, text="BACK", fg="#01579b", command=lambda: self.ClearDatastate11(controller))
        backbutton.pack(side = TOP)
    def saveDatastate11(self , controller): 
        controller.show_frame("Genderlast")
        current.State11= self.v.get()
        
        
            
    def ClearDatastate11(self , controller):
        controller.show_frame("startPage")
        

        
class Gender(Frame):
  
    def __init__(self , parent , controller):
        Frame.__init__(self, parent)
        self.v =  IntVar()
        topFrame = Frame(self, width=720, height=1600, background='#4fc3f7')
        topFrame.pack(fill=X)
    
        MAIN = Frame(topFrame, width=700, height=1500, bd=1, relief="ridge", background='#e4f0ef')
        MAIN.pack(side=TOP, padx=10, pady=10, fill=BOTH)
        Label(MAIN,   text="Gender",    justify = LEFT,   padx = 20).pack()
        rb1 = Radiobutton(MAIN,text="Femaleأنثى",  padx = 20,   variable=self.v, value=1)
        rb1.pack(anchor=CENTER)
        rb2 = Radiobutton(MAIN,text="Maleذكر",padx = 20,variable=self.v,value=2)
        rb2.pack(anchor=CENTER)
        
      
        nextbutton = Button(MAIN, padx=16, bd=8, text="NEXT", fg="#01579b", command=lambda: self.saveDatastate1(controller))
        nextbutton.pack(side = TOP)
        backbutton = Button(MAIN, padx=16, bd=8, text="BACK", fg="#01579b", command=lambda: self.ClearDatastate1(controller))
        backbutton.pack(side = TOP)
        
        
        

    def saveDatastate1(self , controller):

        
        controller.show_frame("lan_Select")
        current.Gender1 = self.v.get() 
       
    def ClearDatastate1(self , controller):
        controller.show_frame("startPage")
        
        
class lan_Select(Frame):
  
    def __init__(self , parent , controller):
        Frame.__init__(self, parent)
        self.v =  IntVar()
        topFrame = Frame(self, width=720, height=1600, background='#4fc3f7')
        topFrame.pack(fill=X)
    
        MAIN = Frame(topFrame, width=700, height=1500, bd=1, relief="ridge", background='#e4f0ef')
        MAIN.pack(side=TOP, padx=10, pady=10, fill=BOTH)
        Label(MAIN,   text="Language",    justify = LEFT,   padx = 20).pack()
        rb1 = Radiobutton(MAIN,text="Arabic",  padx = 20,   variable=self.v, value=1)
        rb1.pack(anchor=CENTER)
        rb2 = Radiobutton(MAIN,text="English",padx = 20,variable=self.v,value=2)
        rb2.pack(anchor=CENTER)
        nextbutton = Button(MAIN, padx=16, bd=8, text="NEXT", fg="#01579b", command=lambda: self.saveDatastate(controller))
        nextbutton.pack(side = TOP)
        backbutton = Button(MAIN, padx=16, bd=8, text="BACK", fg="#01579b", command=lambda: self.ClearDatastate(controller))
        backbutton.pack(side = TOP)
        
      
        
        
        
        

    def saveDatastate(self , controller):

        
        controller.show_frame("LastFrame")
        current.lan1 = self.v.get() 
        en = eng()
        en.person= current
        en.reset()
        en.run()
        
            
    def ClearDatastate(self , controller):
        controller.show_frame("startPage")
        
class Genderlast(Frame):
  
    def __init__(self , parent , controller):
        Frame.__init__(self, parent)
        self.v =  IntVar()
        topFrame = Frame(self, width=720, height=1600, background='#4fc3f7')
        topFrame.pack(fill=X)
    
        MAIN = Frame(topFrame, width=700, height=1500, bd=1, relief="ridge", background='#e4f0ef')
        MAIN.pack(side=TOP, padx=10, pady=10, fill=BOTH)
        Label(MAIN,   text="Gender",    justify = LEFT,   padx = 20).pack()
        rb1 = Radiobutton(MAIN,text="Female",  padx = 20,   variable=self.v, value=1)
        rb1.pack(anchor=CENTER)
        rb2 = Radiobutton(MAIN,text="Male",padx = 20,variable=self.v,value=2)
        rb2.pack(anchor=CENTER)
        nextbutton = Button(MAIN, padx=16, bd=8, text="NEXT", fg="#01579b", command=lambda: self.saveDatastate(controller))
        nextbutton.pack(side = TOP)
        backbutton = Button(MAIN, padx=16, bd=8, text="BACK", fg="#01579b", command=lambda: self.ClearDatastate(controller))
        backbutton.pack(side = TOP)
        
      
        
        
        
        

    def saveDatastate(self , controller):

        
        controller.show_frame("LastFrame")
        current.Gender2 = self.v.get() 
        en = eng()
        en.person= current
        en.reset()
        en.run()
       
        
            
    def ClearDatastate(self , controller):
        controller.show_frame("startPage")
        

        
        
class Sele(Frame):
  
    def __init__(self , parent , controller):
        Frame.__init__(self, parent)
        self.v =  IntVar()
        topFrame = Frame(self, width=720, height=1600, background='#4fc3f7')
        topFrame.pack(fill=X)
    
        MAIN = Frame(topFrame, width=700, height=1500, bd=1, relief="ridge", background='#e4f0ef')
        MAIN.pack(side=TOP, padx=10, pady=10, fill=BOTH)
        Label(MAIN,   text="Select",    justify = LEFT,   padx = 20).pack()
        rb1 = Radiobutton(MAIN,text="Nationalوطني",  padx = 20,   variable=self.v, value=1)
        rb1.pack(anchor=CENTER)
        rb2 = Radiobutton(MAIN,text="Stateحالة اجتماعية",padx = 20,variable=self.v,value=2)
        rb2.pack(anchor=CENTER)
        nextbutton = Button(MAIN, padx=16, bd=8, text="NEXT", fg="#01579b", command=lambda: self.saveDatase(controller))
        nextbutton.pack(side = TOP)
        backbutton = Button(MAIN, padx=16, bd=8, text="BACK", fg="#01579b", command=lambda: self.ClearDatase(controller))
        backbutton.pack(side = TOP)
      
       
        
        
        

    def saveDatase(self , controller):

        
        if (self.v.get() == 1 ):
            controller.show_frame("LastFrame")
            current.Sele1 = self.v.get()
            en = eng()
            en.person= current
            en.reset()
            en.run()
        if (self.v.get() == 2 ):
            controller.show_frame("State")
            current.Sele1 = self.v.get() 
            
            
        
            
    def ClearDatase(self , controller):
        controller.show_frame("startPage")


################################################################################################################        
class  Malad_select(Frame) :
    def __init__(self , parent , controller):
        Frame.__init__(self, parent)
        self.v =  IntVar()
        self.name = StringVar()
        
        topFrame = Frame(self, width=720, height=1600, background='#4fc3f7')
        topFrame.pack(fill=X)
        #Label(topFrame,   text="customer information",    justify = CENTER,   padx = 100).pack()
        
        MAIN = Frame(topFrame, width=700, height=1500, bd=1, relief="ridge", background='#e4f0ef')
        MAIN.pack(side=BOTTOM, padx=10, pady=10, fill=BOTH)
        
        Label(MAIN,   text="Malad",    justify = LEFT,   padx = 20).pack()
        rb1 = Radiobutton(MAIN,text="Depressionاكتئاب ",  padx = 20,   variable=self.v, value=0)
        rb1.pack(anchor=CENTER)
        rb2 = Radiobutton(MAIN,text="High blood pressure ضغط دم مرتفع",padx = 20,variable=self.v,value=1)
        rb2.pack(anchor=CENTER)
        rb3 = Radiobutton(MAIN,text="Low Blood Pressure ضغط دم منخفض",  padx = 20,   variable=self.v, value=2)
        rb3.pack(anchor=CENTER)
        rb4 = Radiobutton(MAIN,text="Alzheimer disease زهايمر",padx = 20,variable=self.v,value=3)
        rb4.pack(anchor=CENTER)
        rb5 = Radiobutton(MAIN,text="Dizziness دوار",  padx = 20,   variable=self.v, value=4)
        rb5.pack(anchor=CENTER) 
        rb6 = Radiobutton(MAIN,text="Pregnancy حمل",  padx = 20,   variable=self.v, value=5)
        rb6.pack(anchor=CENTER) 
        rb7 = Radiobutton(MAIN,text="Cancer سرطان",  padx = 20,   variable=self.v, value=6)
        rb7.pack(anchor=CENTER) 
        rb8 = Radiobutton(MAIN,text="Heart قلب",  padx = 20,   variable=self.v, value=7)
        rb8.pack(anchor=CENTER) 
        rb9 = Radiobutton(MAIN,text="Tinnitus طنين الاذن",  padx = 20,   variable=self.v, value=8)
        rb9.pack(anchor=CENTER) 
        rb10 = Radiobutton(MAIN,text="Insomnia أرق",  padx = 20,   variable=self.v, value=9)
        rb10.pack(anchor=CENTER) 
        rb11 = Radiobutton(MAIN,text="Autism توحد",  padx = 20,   variable=self.v, value=10)
        rb11.pack(anchor=CENTER)
      
        
        nextbutton = Button(MAIN, padx=16, bd=8, text="NEXT", fg="#01579b", command=lambda: self.saveDatamalad(controller))
        nextbutton.pack(side = TOP)
        backbutton = Button(MAIN, padx=16, bd=8, text="BACK", fg="#01579b", command=lambda: self.ClearDatamalad(controller))
        backbutton.pack(side = TOP)
        
      

    def saveDatamalad(self , controller):
        controller.show_frame("LastFrame")
        current.malad = self.v.get() 
        en = eng()
        en.person= current
        en.reset()
        en.run()
       
        
    def ClearDatamalad(self , controller):
        controller.show_frame("Health_select")
        
  
    

###########################
########################
####################
################
############
########
####
class  Malad_select_Child(Frame) :
    def __init__(self , parent , controller):
        Frame.__init__(self, parent)
        self.v =  IntVar()
        self.name = StringVar()
        
        topFrame = Frame(self, width=720, height=1600, background='#4fc3f7')
        topFrame.pack(fill=X) 
        MAIN = Frame(topFrame, width=700, height=1500, bd=1, relief="ridge", background='#e4f0ef')
        MAIN.pack(side=BOTTOM, padx=10, pady=10, fill=BOTH)    
        Label(MAIN,   text="MALAD CHILD",    justify = LEFT,   padx = 20).pack()
        rb1 = Radiobutton(MAIN,text="Depressionاكتئاب",  padx = 20,   variable=self.v, value=0)
        rb1.pack(anchor=CENTER)
        rb2 = Radiobutton(MAIN,text="Tinnitusطنين أذن",  padx = 20,   variable=self.v, value=1)
        rb2.pack(anchor=CENTER)
        rb3 = Radiobutton(MAIN,text="Cancerسرطان",  padx = 20,   variable=self.v, value=2)
        rb3.pack(anchor=CENTER) 
        rb4 = Radiobutton(MAIN,text="Dizzinessدوار",  padx = 20,   variable=self.v, value=3)
        rb4.pack(anchor=CENTER)   
        rb5 = Radiobutton(MAIN,text="Sleep Problemمشاكل في النوم",  padx = 20,   variable=self.v, value=4)
        rb5.pack(anchor=CENTER) 
        rb6 = Radiobutton(MAIN,text="Autismتوحد",  padx = 20,   variable=self.v, value=5)
        rb6.pack(anchor=CENTER) 
        rb7 = Radiobutton(MAIN,text="MentalProblemمشاكل ذهنية",  padx = 20,   variable=self.v, value=6)
        rb7.pack(anchor=CENTER) 

        nextbutton = Button(MAIN, padx=16, bd=8, text="NEXT", fg="#01579b", command=lambda: self.saveDatamcc(controller))
        nextbutton.pack(side = TOP)
        backbutton = Button(MAIN, padx=16, bd=8, text="BACK", fg="#01579b", command=lambda: self.ClearDatamcc(controller))
        backbutton.pack(side = TOP)
      

    def saveDatamcc(self , controller):
        controller.show_frame("LastFrame")
        current.maladChild = self.v.get() 
        en = eng()
        en.person= current
        en.reset()
        en.run()
       
    
        
    def ClearDatamcc(self , controller):
        controller.show_frame("Health_select")
        
        
        
 ####################       
class  Health_select_Child(Frame) :
    def __init__(self , parent , controller):
        Frame.__init__(self, parent)
        self.v =  IntVar()
        self.name = StringVar()
        
        topFrame = Frame(self, width=720, height=1600, background='#4fc3f7')
        topFrame.pack(fill=X)
       
        
        MAIN = Frame(topFrame, width=700, height=1500, bd=1, relief="ridge", background='#e4f0ef')
        MAIN.pack(side=BOTTOM, padx=10, pady=10, fill=BOTH)
        
        Label(MAIN,   text="time",    justify = LEFT,   padx = 20).pack()
        rb1 = Radiobutton(MAIN,text="Sleeping",  padx = 20,   variable=self.v, value=0)
        rb1.pack(anchor=CENTER)
        rb2 = Radiobutton(MAIN,text="Learning ",padx = 20,variable=self.v,value=1)
        rb2.pack(anchor=CENTER)
        rb3 = Radiobutton(MAIN,text="Morning",  padx = 20,   variable=self.v, value=2)
        rb3.pack(anchor=CENTER)
        rb4 = Radiobutton(MAIN,text="Motivation ",padx = 20,variable=self.v,value=3)
        rb4.pack(anchor=CENTER)
  
        
        nextbutton = Button(MAIN, padx=16, bd=8, text="NEXT", fg="#01579b", command=lambda: self.saveDatatc(controller))
        nextbutton.pack(side = TOP)
        backbutton = Button(MAIN, padx=16, bd=8, text="BACK", fg="#01579b", command=lambda: self.ClearDatatc(controller))
        backbutton.pack(side = TOP)
    

    def saveDatatc(self , controller):
        
        controller.show_frame("LastFrame")
        current.timeChild = self.v.get() 
        en = eng()
        en.person= current
        en.reset()
        en.run()
        
        
       
        
    def ClearDatatc(self , controller):
        controller.show_frame("Health_select")
 ###################################################################################################################       
class LastFrame(Frame):
  
    def __init__(self , parent , controller):
        Frame.__init__(self, parent)
        self.v =  IntVar()
        topFrame = Frame(self, width=720, height=1600, background='#4fc3f7')
        topFrame.pack(fill=X)
       
        MAIN = Frame(topFrame, width=700, height=1500, bd=1, relief="ridge", background='#e4f0ef')
        MAIN.pack(side=BOTTOM, padx=10, pady=10, fill=BOTH)
        
        #Label(MAIN,   text="Music Information",    justify = LEFT,   padx = 20).pack()
        RIGHTFRAME = Frame(topFrame, width=700, height=1500, bd=1, relief="ridge", background='#e4f0ef')
        RIGHTFRAME.pack(side=TOP, padx=10, pady=10, fill=BOTH)
        
        RIGHTLABEL = Label(RIGHTFRAME, font=('arial', 12, 'bold'), bd=5, text="MUSIC", anchor=E,
                   background='#e4f0ef')
        RIGHTLABEL.pack()

        Stopbutton = Button(MAIN, padx=16, bd=8, text="Stop", fg="#01579b", command=lambda: self.stopMusic(controller))
        Stopbutton.pack(side = TOP)
        
        backbutton = Button(MAIN, padx=16, bd=8, text="Exit", fg="#01579b", command=lambda: self.ClearDataLast(controller))
        backbutton.pack(side = TOP)
        
    def stopMusic(self, controller):
        mixer.music.stop()

        
    def ClearDataLast(self , controller):
        tem.listbox.delete(0)
        controller.show_frame("startPage")
        
        
        
 


if __name__ == "__main__":
  
    root = SampleApp()

    root.mainloop()
# Out:
# mimi  1
# age  > 16  1
# سليم
# End Of Day
# Deprission
# هي لمرض صعوبة النوم.mp3
